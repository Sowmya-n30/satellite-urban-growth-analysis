# %% [markdown]
# # 01 – Exploratory Data Analysis
#
# Analyse Sentinel-2 satellite imagery for Vijayawada.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import numpy as np
import matplotlib.pyplot as plt

print("EDA notebook ready.")

# %% [markdown]
# ## 1. Load Configuration

# %%
import yaml
with open('../config/config.yaml') as f:
    cfg = yaml.safe_load(f)
print("ROI:", cfg['roi'])

# %% [markdown]
# ## 2. GEE Connection

# %%
try:
    import ee
    ee.Authenticate()
    ee.Initialize()
    print("GEE initialized.")
except Exception as e:
    print(f"GEE unavailable: {e}")

# %% [markdown]
# ## 3. Visualize Spectral Indices
#
# Once data is downloaded, load and visualize.

# %%
from src.data.preprocessing import read_geotiff, normalize_image, add_spectral_indices, compute_ndvi, compute_ndbi
from src.visualization.plots import plot_rgb, plot_spectral_bands

# Example (replace path with actual file)
# image, profile = read_geotiff("../data/raw/vijayawada_2023.tif")
# image_norm = normalize_image(image)
# plot_rgb(image_norm, title="Vijayawada 2023 RGB")
print("Preprocessing utilities loaded.")
