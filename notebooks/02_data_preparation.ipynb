# %% [markdown]
# # 02 – Data Preparation
#
# Extract patches and prepare train/val/test datasets.

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))
import numpy as np
print("Imports OK")

# %% [markdown]
# ## 1. Extract Patches from GeoTIFF

# %%
from src.data.preprocessing import read_geotiff, normalize_image, add_spectral_indices, extract_patches, save_patches, split_dataset

# Example workflow:
# image, profile = read_geotiff("../data/raw/vijayawada_2023.tif")
# mask, _ = read_geotiff("../data/raw/vijayawada_mask.tif")
# image = normalize_image(image)
# image = add_spectral_indices(image)
# img_patches, msk_patches = extract_patches(image, mask[:,:,0].astype(int))
# save_patches(img_patches, msk_patches, "../data/processed/patches")
print("Patch extraction utilities ready.")

# %% [markdown]
# ## 2. Split into Train/Val/Test (70/15/15)

# %%
# split_dataset(
#     image_dir="../data/processed/patches/images",
#     mask_dir="../data/processed/patches/masks",
#     output_dir="../data/processed/",
# )
print("Split utilities ready.")

# %% [markdown]
# ## 3. Create DataLoaders

# %%
from src.data.dataloader import get_dataloaders
# train_loader, val_loader, test_loader, stats = get_dataloaders("../data/processed/")
# print(f"Train: {len(train_loader)} batches")
print("DataLoader factory ready.")
