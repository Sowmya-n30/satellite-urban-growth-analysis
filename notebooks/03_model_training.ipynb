# %% [markdown]
# # 03 – Model Training
#
# Train deep learning models for urban segmentation.

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))
import torch
print(f"PyTorch {torch.__version__} | CUDA: {torch.cuda.is_available()}")

# %% [markdown]
# ## 1. Build Model

# %%
from src.models.unet import build_unet
from src.models.resnet import build_resnet50_segmenter
from src.models.efficientnet import build_efficientnet_segmenter

# Build U-Net (recommended for segmentation)
model = build_unet(in_channels=15, num_classes=3)
total, trainable = model.get_num_parameters()
print(f"U-Net | Parameters: {total:,}")

# %% [markdown]
# ## 2. Configure Loss & Optimizer

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from src.models.losses import get_loss_function

loss_fn = get_loss_function("combined")
optimizer = optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)
scheduler = CosineAnnealingLR(optimizer, T_max=100, eta_min=1e-6)
print("Loss, optimizer, scheduler configured.")

# %% [markdown]
# ## 3. Training Loop

# %%
from src.training.trainer import Trainer

# trainer = Trainer(model, optimizer, loss_fn, scheduler, num_classes=3)
# history = trainer.fit(train_loader, val_loader, epochs=100)
print("Trainer ready. Provide train_loader and val_loader to start training.")

# %% [markdown]
# ## 4. Plot Training History

# %%
from src.visualization.plots import plot_training_history
# plot_training_history(history, output_path="../results/visualizations/training_history.png")
print("Plotting utilities ready.")
