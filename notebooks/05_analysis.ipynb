# %% [markdown]
# # 05 – Urban Growth Analysis
#
# Analyse and report urban expansion in Vijayawada 2020–2023.

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))
import numpy as np
import matplotlib.pyplot as plt
print("Imports OK")

# %% [markdown]
# ## 1. Change Detection (2020 vs 2023)

# %%
from src.inference.postprocessing import compute_change_statistics

# Assuming pred_2020 and pred_2023 are loaded:
# change_stats = compute_change_statistics(pred_2020, pred_2023)
# print(f"Urban growth: +{change_stats['urban_growth_km2']} km² ({change_stats['urban_growth_percent']}%)")
print("Change detection utilities ready.")

# %% [markdown]
# ## 2. Visualize Change Detection

# %%
from src.visualization.plots import plot_change_heatmap, plot_classification_map
# change_map = (pred_2023 == 2).astype(float) - (pred_2020 == 2).astype(float)
# plot_change_heatmap(change_map, title="Vijayawada Urban Growth 2020-2023")
# plot_classification_map(pred_2023, title="Vijayawada 2023 Classification")
print("Visualization utilities ready.")

# %% [markdown]
# ## 3. Generate Reports

# %%
from src.visualization.reports import generate_html_report, generate_markdown_report

# generate_html_report(change_stats, output_path="../results/reports/urban_growth_report.html")
# generate_markdown_report(change_stats, output_path="../results/reports/urban_growth_report.md")
print("Report generation utilities ready.")

# %% [markdown]
# ## 4. Urban Statistics Dashboard

# %%
# Example statistics output format:
example_stats = {
    "urban_area_t1_km2": 85.2,
    "urban_area_t2_km2": 112.7,
    "urban_growth_km2": 27.5,
    "urban_growth_percent": 32.3,
    "new_urban_area_km2": 27.5,
}
for k, v in example_stats.items():
    print(f"  {k}: {v}")
